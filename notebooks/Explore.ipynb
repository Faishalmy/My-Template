# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import os

# %%
img = cv.imread("d:\One Drive\Album Foto\puninoth _7.jpg")

# %%
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
import
    matplotlib.pyplot as plt
